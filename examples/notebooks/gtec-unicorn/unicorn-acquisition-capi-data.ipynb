# %% [markdown]
# # WIP: Unicorn Data-Acquisition via their c-API

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
unicorn_data_container = '~/projects/unicorn-acquisition/x64/Release/'

# %% [markdown]
# ### Acquisition Configuration:
# - **Sampling Rate**: 250Hz
# - **Frame Length**: 1
# - **Number Of Acquired Channels**: 17

# %%
number_of_channels = 17
sampling_rate = 250

# %%
unicorn_data_files = [f
                      for f in os.listdir(unicorn_data_container)
                      if f.startswith('unicorn-') and f.endswith('.out')
                     ]

# %%
[print(i, f) for i, f in enumerate(unicorn_data_files)];

# %%
unicorn_data_idx = 2
unicorn_sample_file = os.path.join(unicorn_data_container, unicorn_data_files[unicorn_data_idx])
unicorn_sample = np.fromfile(unicorn_sample_file)
unicorn_sample.shape, unicorn_sample.shape[0]/17

# %%
with open(unicorn_sample_file, 'rb') as s:
    l = s.readline()
np.frombuffer(l, dtype=np.float32)

# %%
for i in range(number_of_channels):
    plt.semilogy(np.absolute(unicorn_sample[i::17]))

# %%
plt.semilogy(unicorn_sample[0::17])
plt.semilogy(unicorn_sample[1::17])
plt.semilogy(unicorn_sample[2::17])
plt.semilogy(unicorn_sample[3::17])

# %%
plt.figure(figsize=(15,5))
plt.plot(unicorn_sample[4::17])
# 0  to ~10: eyes open 
# 10 to ~20: eyes cloes
# 20 to ~30: teath clenshing each second

plt.ylim([0.0075, 0.01])

# %%
plt.plot(unicorn_sample[5::17])
plt.ylim([-1e-2, 1e-2])

# %%
plt.plot(unicorn_sample[6::17])
plt.ylim([-1e1, 1e1])

# %%
plt.plot(unicorn_sample[6::17])
plt.ylim([-1, 1])

# %%
plt.plot(unicorn_sample[7::17])

# %%
plt.semilogy(unicorn_sample[8::17])

# %%
plt.semilogy(unicorn_sample[9::17])

# %%
plt.semilogy(unicorn_sample[10::17])

# %%
plt.semilogy(unicorn_sample[11::17])

# %%
plt.plot(unicorn_sample[12::17])

# %%
plt.plot(unicorn_sample[13::17])

# %%
plt.plot(unicorn_sample[14::17])

# %%
plt.semilogy(unicorn_sample[15::17])

# %%
plt.plot(unicorn_sample[16::17])
